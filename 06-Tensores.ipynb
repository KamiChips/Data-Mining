# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/googleplaystore.csv"
df = pd.read_csv(url)
print(len(df))
# Out:
# 10841

# %%
dd = df.duplicated(subset=['App']).sum()
print(dd)
# Out:
# 1181

# %%
deleted = df.drop_duplicates(subset=['App'], keep='first', inplace=True)

print(len(df))
# Out:
# 9660

# %% [markdown]
# Pregunta A
# Se purgaron los 1181 registros que eran duplicados de la columna 'App'.

# %%
df['Installs'].unique()
# Out:
# array(['10,000', '500,000', '5,000,000', '50,000,000', '100,000',
#        '50,000', '1,000,000', '10,000,000', '5,000', '100,000,000',
#        '1,000,000,000', '1,000', '500,000,000', '50', '100', '500', '10',
#        '1', '5', '0', 'Free'], dtype=object)

# %%
df[df['Installs'] == 'Free'].T
# Out:
#                                                   10472
# App             Life Made WI-Fi Touchscreen Photo Frame
# Category                                            1.9
# Rating                                             19.0
# Reviews                                            3.0M
# Size                                             1,000+
# Installs                                           Free
# Type                                                  0
# Price                                          Everyone
# Content Rating                                      NaN
# Genres                                February 11, 2018
# Last Updated                                     1.0.19
# Current Ver                                  4.0 and up
# Android Ver                                         NaN

# %%
df = df.drop(index=10472)

# %%
df['Installs'] = (df['Installs'].str.replace('+', '', regex=False).str.replace(',', '', regex=False).astype(float))
df['Installs'].mean()
# Out:
# np.float64(7777506.732270421)

# %% [markdown]
# Pregunta B

# %% [markdown]
# El promedio de descargas es de 7,777,506.

# %% [markdown]
# PREGUNTA C

# %%
df['Price'] = df['Price'].str.replace('$', '', regex=False).astype(float)

# %% [markdown]
# PREGUNTA D

# %%
df['Price'].max()
# Out:
# 400.0

# %%
df[df['Price'] > 200]
# Out:
#                                     App   Category  Rating Reviews  Size  \
# 4197             most expensive app (H)     FAMILY     4.3       6  1.5M
# 4362                         💎 I'm rich  LIFESTYLE     3.8     718   26M
# 4367           I'm Rich - Trump Edition  LIFESTYLE     3.6     275  7.3M
# 5351                          I am rich  LIFESTYLE     3.8    3547  1.8M
# 5354                     I am Rich Plus     FAMILY     4.0     856  8.7M
# 5355                      I am rich VIP  LIFESTYLE     3.8     411  2.6M
# 5356                  I Am Rich Premium    FINANCE     4.1    1867  4.7M
# 5357                I am extremely Rich  LIFESTYLE     2.9      41  2.9M
# 5358                         I am Rich!    FINANCE     3.8      93   22M
# 5359                 I am rich(premium)    FINANCE     3.5     472  965k
# 5362                      I Am Rich Pro     FAMILY     4.4     201  2.7M
# 5364     I am rich (Most expensive app)    FINANCE     4.1     129  2.7M
# ...

# %%
df = df[df['Price'] < 50]

# %%
df.to_csv('playstore_limpio.csv', index=False)
