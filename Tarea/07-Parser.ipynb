# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/googleplaystore.csv"
df = pd.read_csv(url)
print(len(df))
# Out:
# 10841

# %%
def convertir_size(size):
    if size == "Varies with device":
        return np.nan
    elif size.endswith('M'):
        return float(size[:1])
    elif size.endswith("k"):
        return float(size[:-1])/1024

# %%
df['Size'] = df['Size'].apply(convertir_size)

# %%
media = df['Size'].mean()
print(media)
# Out:
# 3.461315791159787

# %% [markdown]
# ### RETO 1
# Promedio de megabytes: 3.4613

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'], errors="coerce")

# %%
df['Year Updated'] = df['Last Updated'].dt.year
df['Year Updated'].value_counts().sort_index
# Out:
# <bound method Series.sort_index of Year Updated
# 2018.0    7349
# 2017.0    1867
# 2016.0     804
# 2015.0     459
# 2014.0     209
# 2013.0     110
# 2012.0      26
# 2011.0      15
# 2010.0       1
# Name: count, dtype: int64>

# %% [markdown]
# ### RETO 2
# En el año 2018 fue cuando más aplicaciones se actualizaron.

# %%
df['Size'].isna().sum()
# Out:
# np.int64(1696)

# %% [markdown]
# En este caso es preferible rellenar los datos faltantes con la mediana global, para intentar mantener la mayoria de datos posibles. Eliminar las filas nos reduciría la cantidad de datos de entrenamiento además de que estaríamos perdiendo información útil para un modelo. Además de que la mediana es menos "sensible" a cambio de valores extremos como lo es la media, ya que si tenemos valores de 10, 15, 23, 20, 400 -> así se vera afectado el promedio, mientras que la media se mantendría como 23.
