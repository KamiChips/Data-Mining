# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/googleplaystore.csv"
df = pd.read_csv(url)
print(len(df))
# Out:
# 10841

# %%
df['Size'] = (df['Size'].str.replace('M', '', regex=False).str.replace('k', '', regex=False).astype(float))
